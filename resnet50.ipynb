# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import src.train

# %%
hyperparameters = {
    "lr": 1e-3,
    "weight_decay": 1e-8,
    "batch_size": 32
}
addendum = ""

src.train.train(batch_size=hyperparameters["batch_size"],
                learning_rate=hyperparameters["lr"], 
                weight_decay=hyperparameters["weight_decay"],
                version_name= f'bs={hyperparameters["batch_size"]}-lr={hyperparameters["lr"]}-wd={hyperparameters["weight_decay"]}-{addendum}',
                test_mode=False)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type             | Params
# -----------------------------------------------
# 0 | extractor | ResNet           | 25.6 M
# 1 | fc1       | Linear           | 600 K
# 2 | dropout1  | Dropout          | 0
# 3 | fc2       | Linear           | 120 K
# 4 | dropout2  | Dropout          | 0
# 5 | fc3       | Linear           | 1.6 K
# 6 | train_acc | Accuracy         | 0
# 7 | val_acc   | Accuracy         | 0
# 8 | loss      | CrossEntropyLoss | 0
# -----------------------------------------------
# 2.8 M     Trainable params
# 23.5 M    Non-trainable params
# 26.3 M    Total params
# 105.118   Total estimated model params size (MB)
# Epoch 0:   6%|▋         | 50/793 [00:18<04:33,  2.72it/s, loss=1.66, v_num=-08-, train_loss=1.820, train_acc_step=0.228]
# ...
